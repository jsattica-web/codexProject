# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. LLM 답변 생성
#
# - `ChatOllama` 를 활용한 LLM 답변 생성
# - 터미널에서 `ollama pull gemma2` 와 같이 원하는 모델을 가져와야 실행 가능

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="exaone3.5")

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '죄송하지만 저는 실시간 정보에 접근할 수 없어 현재 인프런에서 어떤 강의가 있는지 구체적으로 알려드릴 수 없습니다. \n\n하지만 인프런 웹사이트를 직접 방문하시면 다양한 분야의 온라인 강의 목록을 확인하실 수 있습니다! \n\n* **관심 분야를 선택**하시거나, \n* **키워드 검색**을 통해 원하는 강의를 찾아볼 수 있습니다.\n\n혹시 특정 분야나 주제에 대해 궁금한 점이 있다면, 제가 가진 일반 지식으로 최대한 도움을 드리겠습니다. 😊'
