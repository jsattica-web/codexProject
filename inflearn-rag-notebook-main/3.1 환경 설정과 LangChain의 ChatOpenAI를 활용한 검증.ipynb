# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script distro.exe is installed in 'c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 3. LLM 답변 생성
#
# - OpenAI 대시보드에서 발급받은 API Key를 `OPENAI_API_KEY`라고 저장하면 별도의 설정 없이 `ChatOpenAI`를 사용할 수 있음

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model_name='gpt-4o-mini')

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\langchain_openai\chat_models\base.py:1667, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1665     _handle_openai_bad_request(e)
#    1666 except openai.APIError as e:
# -> 1667     _handle_openai_api_error(e)
#    1668 except Exception as e:
#    1669     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\langchain_openai\chat_models\base.py:1662, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1655         return _construct_lc_result_from_responses_api(
#    1656             response,
#    1657             schema=original_schema_obj,
#    1658             metadata=generation_info,
#    1659             output_version=self.output_version,
#    1660         )
#    1661     else:
# -> 1662         raw_response = self.client.with_raw_response.create(**payload)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\openai\resources\chat\completions\completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\sm\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: up_aCoeU********************1cTk. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
ai_message.content
# Out:
# '인프런은 다양한 분야의 온라인 강의를 제공하는 플랫폼으로, 주로 IT 및 프로그래밍 관련 강의가 많습니다. 예를 들어, 다음과 같은 강의들이 있습니다:\n\n1. **프로그래밍 언어**: Python, Java, JavaScript, C++, Ruby 등의 강의\n2. **웹 개발**: HTML, CSS, React, Vue.js, Node.js 등의 프레임워크와 기술에 대한 강의\n3. **모바일 개발**: iOS, Android 개발 관련 강의\n4. **데이터 과학**: 데이터 분석, 머신러닝, 딥러닝 관련 강의\n5. **클라우드 컴퓨팅**: AWS, Azure, GCP 관련 강의\n6. **DevOps**: CI/CD, Docker, Kubernetes 관련 강의\n7. **UI/UX 디자인**: 디자인 원칙, 프로토타이핑 도구 관련 강의\n8. **기타**: 소프트 스킬, 경영, 마케팅 등 다양한 주제의 강의\n\n각 강의는 초급, 중급, 고급으로 나뉘어 있으며, 강의의 길이와 형식도 다양합니다. 더 구체적인 정보는 인프런 웹사이트를 직접 방문하여 확인하시는 것이 좋습니다.'
